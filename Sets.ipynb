# %%
#Set inn python
#Set is a collection of the unordered items\
#Each element in the set must be unique and immutable
nums = {1,2,3,4}
set2 = {1,2,2,2}
#Repeated elements stored only once, so it resolved to{1,2}
null_set = set() #Empty set syntax

# %%
collection = {1,2,3,4 , "Hello" , "world" , "world" , 4}
print(collection)
print(type(collection))
#if we use same word/int etc multiple times. it will just cont it onces
#the set is unordered
print(len(collection))
#using length function it will count only repeating values. it will ignoring the repeating values and just count them ones
# Out:
# {1, 2, 3, 4, 'world', 'Hello'}
# <class 'set'>
# 6

# %%
#Empty set
coll = set ()
print(type(coll))
# Out:
# <class 'set'>

# %%
#Methods of Sets
#set.add(el) #adds an element
#set.remove(el)  #removes the element
#set.clear(el)  #empties the set
#set.pop(el)  #removes a random value
##Sets are mutable
## But elements in it are immutable
# Tuple can pass
#list and dictionary cannot pass

# %%
#Methods of Sets
#set.add(el) #adds an element
coll.add(2)
coll.add(4)
coll.add("G")
coll.add((1,5,7)) 
print(coll)
# Out:
# {(1, 5, 7), 2, 'G', 4}

# %%
#Methods of Sets
#set.clear(el)  #empties the set
a = {1,2,3,4,5}
print(a)
a.clear()
print(len(a))
# Out:
# {1, 2, 3, 4, 5}
# 0

# %%
b = {"Hello", "Salman" , 12 , "Cartoon"}
print(b.pop())
print(b.pop())
# Out:
# Cartoon
# Salman

# %%
#Set OF Method
#set.union(Set2) #combines both set values and returns new
#set.intersection(Set2)#cpmbines common vlues and return new
set3 = {1,2,3}
set4 = {0,2,4}
print(set3.union(set4))
print("Intersection of 1 and 2 is", set3.intersection(set4))
# Out:
# {0, 1, 2, 3, 4}
# Intersection of 1 and 2 is {2}

# %%
#Pratice 
#Store following word meaning in python dictionary:
dictionary = {
    "cat" : "A small animal",
    "table"  : ["a peice of furrniture" , "list of facts and figure"]
}
print(dictionary)
# Out:
# {'cat': 'A small animal', 'table': ['a peice of furrniture', 'list of facts and figure']}

# %%
#Pratice 
#You are given  a list of sunject for students.Assume one clssroom is required for 1 subject. How many classrooms are needed by all students.
classroom = {"Python","Java","C++","Python","Javascript","Java","Python", "Java", "C++" ,"C"}
print(len(classroom))
# Out:
# 5
