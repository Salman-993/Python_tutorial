# %%
#Reding File
data = f.read() #reads entire file
data = f.readline() #reads one line at a time

# %%
# This is reading file
f = open("demo.txt", "r")
data = f.read()
print(data)
print(type(data))
f.close()
# Out:
# abcd is the new line
# Then is is also Append used for updating data
# Then is is also Append used for updating data
# Then is is also Append used for updating data
# <class 'str'>

# %%
#'r' open for reading(default)
#  'w' open for writing,truncating the file first
#  'x' create a new file and open it for writing
#  'a' open file for writing, append to the end of the file if it exists     #  'b' binary mode
#  't' text  mode(defalut)
#  '+' open  disk file for updating(reading and writing)

# %%
f = open("demo.txt", "r")
data = f.read(5)
print(data)

f.close()
# Out:
# abcd

# %%
f = open("demo.txt", "r")
data = f.readline()
print(data)
f.close()
# Out:
# I am Salman

# %%
f = open("demo.txt", "r")
line1 = f.readline()
line2 = f.readline()
print(line1)
print(line2)
f.close()
# Out:
# i am Salman
#
# i am a futures multi millioniare bussiness man

# %%
#append means "Add at the END"
f = open("demo.txt","w")
f.write("this is the new line") #overwrites the entire line
f.close()

# %%
f = open("demo.txt" , "a")
f.write("\nThen is is also Append used for updating data")
f.close()
#if we open a file in w write mode and if the file does not even exist ,so python will create a new file by it self
x = open("New.txt", "w")
x.close()

# %%
f = open("demo.txt" , "r+") #r+ is used to over write #it will not delete the entire line but it will over write the line this will prevent the file from being trancated
f.write("abcd")
s = f.read()
f.close()

0
print(s)
# Out:
#  is the new line
# Then is is also Append used for updating data
# Then is is also Append used for updating data
# Then is is also Append used for updating data

# %%
f= open("demo.txt" , "a")
f.write("\nThis is also append")

f.close()
