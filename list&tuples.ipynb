# %%
marks =[21,34,56.6,66.7,12,1,2,32,4,5,6,7,8,89]
print(marks)
print(type(marks))
print(len(marks))
print(marks[0:14:2])
# Out:
# [21, 34, 56.6, 66.7, 12, 1, 2, 32, 4, 5, 6, 7, 8, 89]
# <class 'list'>
# 14
# [21, 56.6, 12, 2, 4, 6, 8]
